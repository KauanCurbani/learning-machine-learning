# %%
from sklearn.datasets import load_iris
iris = load_iris()
x= iris.data
y= iris.target

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
performance_values = {}
k = 1

while k <= 25:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    predicts = knn.predict(x_test)
    goals = metrics.accuracy_score(y_test, predicts)
    performance_values[k] = round(goals,4)
    k += 1

print(performance_values)
# Out:
# {1: 0.9474, 2: 0.8947, 3: 0.9211, 4: 0.8684, 5: 0.9211, 6: 0.9211, 7: 0.9474, 8: 0.8947, 9: 0.8947, 10: 0.8684, 11: 0.8947, 12: 0.8947, 13: 0.8947, 14: 0.8684, 15: 0.8947, 16: 0.8684, 17: 0.9211, 18: 0.8947, 19: 0.9211, 20: 0.8947, 21: 0.8947, 22: 0.8684, 23: 0.8947, 24: 0.8947, 25: 0.8947}

# %%
import matplotlib.pyplot as plt

plt.plot(list(performance_values.keys()), list(performance_values.values()))
plt.xlabel("Valores de K")
plt.ylabel("Precisão")
# Out:
# Text(0, 0.5, 'Precisão')
